# %% [markdown]
# <a href="https://colab.research.google.com/github/juanjosedelgado-coder/Talleres/blob/main/Taller_importaci%C3%B3n_combinaci%C3%B3n_exportaci%C3%B3n_de_datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Taller importación, combinación y exportación de datos**
# **Integrantes:**
# 1.   Natalia Vargas
# 2.   Marleny Cuaspud
# 3.   Juan Jose Delgado

# %%
import pandas as pd
import os
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pd.options.display.max_columns = None
pd.options.display.float_format = "{:,.2f}".format

# %%
ruta = "/content/drive/MyDrive/IA Economia/Taller importación, combinación y exportación de datos/GEIH 2025 (julio,diciembre)"

# %%
os.listdir(ruta)
# Out:
# ['Julio 2025',
#  'Junio 2025',
#  'Agosto 2025',
#  'Noviembre 2025',
#  'Diciembre 2025',
#  'Septiembre 2025',
#  'Octubre 2025']

# %%
os.listdir("/content/drive/MyDrive/IA Economia/Taller importación, combinación y exportación de datos/GEIH 2025 (julio,diciembre)/Julio 2025")
# Out:
# ['CSV', 'SAV', 'DTA']

# %% [markdown]
# ##**Mes Junio**

# %%
df_GEIH_junio_caracteristicas= pd.read_csv("/content/drive/MyDrive/IA Economia/Taller importación, combinación y exportación de datos/GEIH 2025 (julio,diciembre)/Junio 2025/CSV/Características generales, seguridad social en salud y educación.CSV", sep = ";")

# %%
df_GEIH_junio_hogar= pd.read_csv("/content/drive/MyDrive/IA Economia/Taller importación, combinación y exportación de datos/GEIH 2025 (julio,diciembre)/Junio 2025/CSV/Datos del hogar y la vivienda.CSV", sep= ";")

# %%
df_GEIH_junio_fuerza= pd.read_csv("/content/drive/MyDrive/IA Economia/Taller importación, combinación y exportación de datos/GEIH 2025 (julio,diciembre)/Junio 2025/CSV/Fuerza de trabajo.CSV", sep=";", encoding='latin1')
# Out:
# /tmp/ipykernel_849/3181175137.py:1: DtypeWarning: Columns (33) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_GEIH_junio_fuerza= pd.read_csv("/content/drive/MyDrive/IA Economia/Taller importación, combinación y exportación de datos/GEIH 2025 (julio,diciembre)/Junio 2025/CSV/Fuerza de trabajo.CSV", sep=";", encoding='latin1')

# %%
df_GEIH_junio_ocupados= pd.read_csv("/content/drive/MyDrive/IA Economia/Taller importación, combinación y exportación de datos/GEIH 2025 (julio,diciembre)/Junio 2025/CSV/Ocupados.CSV",sep =";", encoding='latin1')
# Out:
# /tmp/ipykernel_849/3666444296.py:1: DtypeWarning: Columns (28,89,133,147,158) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_GEIH_junio_ocupados= pd.read_csv("/content/drive/MyDrive/IA Economia/Taller importación, combinación y exportación de datos/GEIH 2025 (julio,diciembre)/Junio 2025/CSV/Ocupados.CSV",sep =";", encoding='latin1')

# %%
df_junio = pd.concat([df_GEIH_junio_caracteristicas,df_GEIH_junio_hogar,df_GEIH_junio_fuerza,df_GEIH_junio_ocupados], axis= 1,)
df_junio
# Out:
#         PERIODO  MES   PER  DIRECTORIO  SECUENCIA_P  ORDEN  HOGAR  REGIS  \
# 0      20250626    6  2025     8238974            1      1      1     10
# 1      20250626    6  2025     8238974            1      2      1     10
# 2      20250626    6  2025     8238975            1      1      1     10
# 3      20250626    6  2025     8238975            1      2      1     10
# 4      20250626    6  2025     8238975            1      3      1     10
# ...         ...  ...   ...         ...          ...    ...    ...    ...
# 67851  20250626    6  2025     8283060            1      1      1     10
# 67852  20250626    6  2025     8283060            1      2      1     10
# 67853  20250626    6  2025     8283062            1      1      1     10
# 67854  20250626    6  2025     8283062            1      2      1     10
# 67855  20250626    6  2025     8283062            1      3      1     10
#
#        AREA  CLASE  FEX_C18  DPTO  PT  P6016  P3271  P6040  P6030S1  P6030S3  \
# ...

# %%
print(df_junio.shape)
print(df_junio.columns)
# Out:
# (67856, 348)
# Index(['PERIODO', 'MES', 'PER', 'DIRECTORIO', 'SECUENCIA_P', 'ORDEN', 'HOGAR',
#        'REGIS', 'AREA', 'CLASE',
#        ...
#        'P1881', 'P1881S1', 'P1882', 'P7240', 'P7240S1', 'OCI', 'INGLABO',
#        'RAMA2D_R4', 'RAMA4D_R4', 'OFICIO_C8'],
#       dtype='object', length=348)

# %% [markdown]
# ##**Mes Julio**

# %%
df_GEIH_julio_caracteristicas = pd.read_csv("/content/drive/MyDrive/IA Economia/Taller importación, combinación y exportación de datos/GEIH 2025 (julio,diciembre)/Julio 2025/CSV/Características generales, seguridad social en salud y educación.CSV", sep = ";")

# %%
df_GEIH_julio_hogar = pd.read_csv("/content/drive/MyDrive/IA Economia/Taller importación, combinación y exportación de datos/GEIH 2025 (julio,diciembre)/Julio 2025/CSV/Datos del hogar y la vivienda.CSV", sep= ";")

# %%
df_GEIH_julio_fuerza = pd.read_csv("/content/drive/MyDrive/IA Economia/Taller importación, combinación y exportación de datos/GEIH 2025 (julio,diciembre)/Julio 2025/CSV/Fuerza de trabajo.CSV", sep = ";", encoding='latin1')

# %%
df_GEIH_julio_ocupados = pd.read_csv("/content/drive/MyDrive/IA Economia/Taller importación, combinación y exportación de datos/GEIH 2025 (julio,diciembre)/Julio 2025/CSV/Ocupados.CSV", sep = ";", encoding='latin1')
# Out:
# /tmp/ipykernel_849/400785845.py:1: DtypeWarning: Columns (28,89,147,158) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_GEIH_julio_ocupados = pd.read_csv("/content/drive/MyDrive/IA Economia/Taller importación, combinación y exportación de datos/GEIH 2025 (julio,diciembre)/Julio 2025/CSV/Ocupados.CSV", sep = ";", encoding='latin1')

# %%
df_julio = pd.concat([df_GEIH_julio_caracteristicas,df_GEIH_julio_hogar,df_GEIH_julio_fuerza,df_GEIH_julio_ocupados], axis= 1,)
df_julio
# Out:
#         PERIODO  MES   PER  DIRECTORIO  SECUENCIA_P  ORDEN  HOGAR  REGIS  \
# 0      20250731    7  2025     8283143            1      1      1     10
# 1      20250731    7  2025     8283143            1      2      1     10
# 2      20250731    7  2025     8283145            1      1      1     10
# 3      20250731    7  2025     8283145            1      2      1     10
# 4      20250731    7  2025     8283145            1      3      1     10
# ...         ...  ...   ...         ...          ...    ...    ...    ...
# 68431  20250731    7  2025     8316746            1      1      1     10
# 68432  20250731    7  2025     8316746            1      2      1     10
# 68433  20250731    7  2025     8316746            1      3      1     10
# 68434  20250731    7  2025     8316747            1      1      1     10
# 68435  20250731    7  2025     8316747            1      2      1     10
#
#        AREA  CLASE  FEX_C18  DPTO  PT  P6016  P3271  P6040  P6030S1  P6030S3  \
# ...

# %%
print(df_julio.shape)
print(df_julio.columns)
# Out:
# (68436, 348)
# Index(['PERIODO', 'MES', 'PER', 'DIRECTORIO', 'SECUENCIA_P', 'ORDEN', 'HOGAR',
#        'REGIS', 'AREA', 'CLASE',
#        ...
#        'P1881', 'P1881S1', 'P1882', 'P7240', 'P7240S1', 'OCI', 'INGLABO',
#        'RAMA2D_R4', 'RAMA4D_R4', 'OFICIO_C8'],
#       dtype='object', length=348)

# %% [markdown]
# ##**Mes Agosto**

# %%
df_GEIH_agosto_caracteristicas = pd.read_csv("/content/drive/MyDrive/IA Economia/Taller importación, combinación y exportación de datos/GEIH 2025 (julio,diciembre)/Agosto 2025/CSV/Características generales, seguridad social en salud y  educación.CSV", sep =";")

# %%
df_GEIH_agosto_hogar = pd.read_csv("/content/drive/MyDrive/IA Economia/Taller importación, combinación y exportación de datos/GEIH 2025 (julio,diciembre)/Agosto 2025/CSV/Datos del hogar y la vivienda.CSV", sep= ";")

# %%
df_GEIH_agosto_fuerza = pd.read_csv("/content/drive/MyDrive/IA Economia/Taller importación, combinación y exportación de datos/GEIH 2025 (julio,diciembre)/Agosto 2025/CSV/Fuerza de trabajo.CSV",sep=";", encoding='latin1')

# %%
df_GEIH_agosto_ocupados = pd.read_csv("/content/drive/MyDrive/IA Economia/Taller importación, combinación y exportación de datos/GEIH 2025 (julio,diciembre)/Agosto 2025/CSV/Ocupados.CSV", sep=";", encoding='latin1')
# Out:
# /tmp/ipykernel_849/3374900157.py:1: DtypeWarning: Columns (28,89,133,145,147,158) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_GEIH_agosto_ocupados = pd.read_csv("/content/drive/MyDrive/IA Economia/Taller importación, combinación y exportación de datos/GEIH 2025 (julio,diciembre)/Agosto 2025/CSV/Ocupados.CSV", sep=";", encoding='latin1')

# %%
df_agosto = pd.concat([df_GEIH_agosto_caracteristicas,df_GEIH_agosto_hogar,df_GEIH_agosto_fuerza,df_GEIH_agosto_ocupados], axis= 1,)
df_agosto
# Out:
#         PERIODO  MES   PER  DIRECTORIO  SECUENCIA_P  ORDEN  HOGAR  REGIS  \
# 0      20250835    8  2025     8316823            1      1      1     10
# 1      20250835    8  2025     8316823            1      2      1     10
# 2      20250835    8  2025     8316824            1      1      1     10
# 3      20250835    8  2025     8316824            1      2      1     10
# 4      20250835    8  2025     8316825            1      1      1     10
# ...         ...  ...   ...         ...          ...    ...    ...    ...
# 68572  20250834    8  2025     8345514            1      1      1     10
# 68573  20250834    8  2025     8345514            1      2      1     10
# 68574  20250834    8  2025     8345515            1      1      1     10
# 68575  20250834    8  2025     8345515            1      2      1     10
# 68576  20250834    8  2025     8345515            1      3      1     10
#
#        AREA  CLASE  FEX_C18  DPTO  PT  P6016  P3271  P6040  P6030S1  P6030S3  \
# ...

# %%
print(df_agosto.shape)
print(df_agosto.columns)
# Out:
# (68577, 348)
# Index(['PERIODO', 'MES', 'PER', 'DIRECTORIO', 'SECUENCIA_P', 'ORDEN', 'HOGAR',
#        'REGIS', 'AREA', 'CLASE',
#        ...
#        'P1881', 'P1881S1', 'P1882', 'P7240', 'P7240S1', 'OCI', 'INGLABO',
#        'RAMA2D_R4', 'RAMA4D_R4', 'OFICIO_C8'],
#       dtype='object', length=348)

# %% [markdown]
# ##**Mes Septiembre**

# %%
df_GEIH_septiembre_caracteristicas = pd.read_csv("/content/drive/MyDrive/IA Economia/Taller importación, combinación y exportación de datos/GEIH 2025 (julio,diciembre)/Septiembre 2025/CSV/Características generales, seguridad social en salud y educación.CSV", sep = ";")

# %%
df_GEIH_septiembre_hogar = pd.read_csv("/content/drive/MyDrive/IA Economia/Taller importación, combinación y exportación de datos/GEIH 2025 (julio,diciembre)/Septiembre 2025/CSV/Datos del hogar y la vivienda.CSV", sep =";")

# %%
df_GEIH_septiembre_fuerza = pd.read_csv("/content/drive/MyDrive/IA Economia/Taller importación, combinación y exportación de datos/GEIH 2025 (julio,diciembre)/Septiembre 2025/CSV/Fuerza de trabajo.CSV", sep=";", encoding='latin1')
# Out:
# /tmp/ipykernel_849/1092862964.py:1: DtypeWarning: Columns (33) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_GEIH_septiembre_fuerza = pd.read_csv("/content/drive/MyDrive/IA Economia/Taller importación, combinación y exportación de datos/GEIH 2025 (julio,diciembre)/Septiembre 2025/CSV/Fuerza de trabajo.CSV", sep=";", encoding='latin1')

# %%
df_GEIH_septiembre_ocupados = pd.read_csv("/content/drive/MyDrive/IA Economia/Taller importación, combinación y exportación de datos/GEIH 2025 (julio,diciembre)/Septiembre 2025/CSV/Ocupados.CSV", sep=";", encoding='latin1')
# Out:
# /tmp/ipykernel_849/1440063335.py:1: DtypeWarning: Columns (28,89,133,145,147,158) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_GEIH_septiembre_ocupados = pd.read_csv("/content/drive/MyDrive/IA Economia/Taller importación, combinación y exportación de datos/GEIH 2025 (julio,diciembre)/Septiembre 2025/CSV/Ocupados.CSV", sep=";", encoding='latin1')

# %%
df_septiembre = pd.concat([df_GEIH_septiembre_caracteristicas,df_GEIH_septiembre_fuerza,df_GEIH_septiembre_hogar,df_GEIH_septiembre_ocupados], axis= 1,)
df_septiembre
# Out:
#         PERIODO  MES   PER  DIRECTORIO  SECUENCIA_P  ORDEN  HOGAR  REGIS  \
# 0      20250939    9  2025     8345569            1      1      1     10
# 1      20250939    9  2025     8345569            1      2      1     10
# 2      20250939    9  2025     8345570            1      1      1     10
# 3      20250939    9  2025     8345570            1      2      1     10
# 4      20250939    9  2025     8345570            1      3      1     10
# ...         ...  ...   ...         ...          ...    ...    ...    ...
# 68258  20250939    9  2025     8374028            1      3      1     10
# 68259  20250939    9  2025     8374028            1      4      1     10
# 68260  20250939    9  2025     8374030            1      1      1     10
# 68261  20250939    9  2025     8374030            1      2      1     10
# 68262  20250939    9  2025     8374030            1      3      1     10
#
#        AREA  CLASE  FEX_C18  DPTO  PT  P6016  P3271  P6040  P6030S1  P6030S3  \
# ...

# %%
print(df_septiembre.shape)
print(df_septiembre.columns)
# Out:
# (68263, 348)
# Index(['PERIODO', 'MES', 'PER', 'DIRECTORIO', 'SECUENCIA_P', 'ORDEN', 'HOGAR',
#        'REGIS', 'AREA', 'CLASE',
#        ...
#        'P1881', 'P1881S1', 'P1882', 'P7240', 'P7240S1', 'OCI', 'INGLABO',
#        'RAMA2D_R4', 'RAMA4D_R4', 'OFICIO_C8'],
#       dtype='object', length=348)

# %% [markdown]
# ##**Mes Octubre**

# %%
df_GEIH_octubre_caracteristicas = pd.read_csv("/content/drive/MyDrive/IA Economia/Taller importación, combinación y exportación de datos/GEIH 2025 (julio,diciembre)/Octubre 2025/CSV/Características generales, seguridad social en salud y educación.CSV", sep = ";")

# %%
df_GEIH_octubre_hogar = pd.read_csv("/content/drive/MyDrive/IA Economia/Taller importación, combinación y exportación de datos/GEIH 2025 (julio,diciembre)/Octubre 2025/CSV/Datos del hogar y la vivienda.CSV", sep= ";", encoding="latin1")

# %%
df_GEIH_octubre_fuerza = pd.read_csv("/content/drive/MyDrive/IA Economia/Taller importación, combinación y exportación de datos/GEIH 2025 (julio,diciembre)/Octubre 2025/CSV/Fuerza de trabajo.CSV", sep=";", encoding='latin1')
# Out:
# /tmp/ipykernel_849/559804732.py:1: DtypeWarning: Columns (33) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_GEIH_octubre_fuerza = pd.read_csv("/content/drive/MyDrive/IA Economia/Taller importación, combinación y exportación de datos/GEIH 2025 (julio,diciembre)/Octubre 2025/CSV/Fuerza de trabajo.CSV", sep=";", encoding='latin1')

# %%
df_GEIH_octubre_ocupados = pd.read_csv("/content/drive/MyDrive/IA Economia/Taller importación, combinación y exportación de datos/GEIH 2025 (julio,diciembre)/Octubre 2025/CSV/Ocupados.CSV", sep=";", encoding='latin1')
# Out:
# /tmp/ipykernel_849/1827335377.py:1: DtypeWarning: Columns (28,89,133,158) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_GEIH_octubre_ocupados = pd.read_csv("/content/drive/MyDrive/IA Economia/Taller importación, combinación y exportación de datos/GEIH 2025 (julio,diciembre)/Octubre 2025/CSV/Ocupados.CSV", sep=";", encoding='latin1')

# %%
df_octubre = pd.concat([df_GEIH_octubre_caracteristicas,df_GEIH_octubre_hogar,df_GEIH_octubre_fuerza,df_GEIH_octubre_ocupados], axis= 1,)
df_octubre
# Out:
#         PERIODO  MES   PER  DIRECTORIO  SECUENCIA_P  ORDEN  HOGAR  REGIS  \
# 0      20251044   10  2025     8374095            1      1      1     10
# 1      20251044   10  2025     8374095            1      2      1     10
# 2      20251044   10  2025     8374095            1      3      1     10
# 3      20251044   10  2025     8374096            1      1      1     10
# 4      20251044   10  2025     8374096            1      2      1     10
# ...         ...  ...   ...         ...          ...    ...    ...    ...
# 68705  20251044   10  2025     8403014            1      3      1     10
# 68706  20251042   10  2025     8403015            1      1      1     10
# 68707  20251042   10  2025     8403015            1      2      1     10
# 68708  20251042   10  2025     8403015            1      3      1     10
# 68709  20251042   10  2025     8403015            1      4      1     10
#
#        AREA  CLASE  FEX_C18  DPTO  PT  P6016  P3271  P6040  P6030S1  P6030S3  \
# ...

# %%
print(df_octubre.shape)
print(df_octubre.columns)
# Out:
# (68710, 348)
# Index(['PERIODO', 'MES', 'PER', 'DIRECTORIO', 'SECUENCIA_P', 'ORDEN', 'HOGAR',
#        'REGIS', 'AREA', 'CLASE',
#        ...
#        'P1881', 'P1881S1', 'P1882', 'P7240', 'P7240S1', 'OCI', 'INGLABO',
#        'RAMA2D_R4', 'RAMA4D_R4', 'OFICIO_C8'],
#       dtype='object', length=348)

# %% [markdown]
# ##**Mes Noviembre**

# %%
df_GEIH_noviembre_caracteristicas = pd.read_csv("/content/drive/MyDrive/IA Economia/Taller importación, combinación y exportación de datos/GEIH 2025 (julio,diciembre)/Noviembre 2025/CSV/Características generales, seguridad social en salud y educación.CSV", sep = ";")

# %%
df_GEIH_noviembre_hogar = pd.read_csv("/content/drive/MyDrive/IA Economia/Taller importación, combinación y exportación de datos/GEIH 2025 (julio,diciembre)/Noviembre 2025/CSV/Datos del hogar y la vivienda.CSV", sep= ";", encoding="latin1")

# %%
df_GEIH_noviembre_fuerza = pd.read_csv("/content/drive/MyDrive/IA Economia/Taller importación, combinación y exportación de datos/GEIH 2025 (julio,diciembre)/Noviembre 2025/CSV/Fuerza de trabajo.CSV", sep=";", encoding='latin1')
# Out:
# /tmp/ipykernel_849/2815065125.py:1: DtypeWarning: Columns (33) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_GEIH_noviembre_fuerza = pd.read_csv("/content/drive/MyDrive/IA Economia/Taller importación, combinación y exportación de datos/GEIH 2025 (julio,diciembre)/Noviembre 2025/CSV/Fuerza de trabajo.CSV", sep=";", encoding='latin1')

# %%
df_GEIH_noviembre_ocupados = pd.read_csv("/content/drive/MyDrive/IA Economia/Taller importación, combinación y exportación de datos/GEIH 2025 (julio,diciembre)/Noviembre 2025/CSV/Ocupados.CSV", sep=";", encoding='latin1')
# Out:
# /tmp/ipykernel_849/3382469141.py:1: DtypeWarning: Columns (28,89,133,147,158) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_GEIH_noviembre_ocupados = pd.read_csv("/content/drive/MyDrive/IA Economia/Taller importación, combinación y exportación de datos/GEIH 2025 (julio,diciembre)/Noviembre 2025/CSV/Ocupados.CSV", sep=";", encoding='latin1')

# %%
df_noviembre = pd.concat([df_GEIH_noviembre_caracteristicas,df_GEIH_noviembre_hogar,df_GEIH_noviembre_fuerza,df_GEIH_noviembre_ocupados], axis= 1,)
df_noviembre
# Out:
#         PERIODO  MES   PER  DIRECTORIO  SECUENCIA_P  ORDEN  HOGAR  REGIS  \
# 0      20251148   11  2025     8403077            1      1      1     10
# 1      20251148   11  2025     8403079            1      1      1     10
# 2      20251148   11  2025     8403081            1      1      1     10
# 3      20251148   11  2025     8403081            1      2      1     10
# 4      20251148   11  2025     8403081            1      3      1     10
# ...         ...  ...   ...         ...          ...    ...    ...    ...
# 68577  20251148   11  2025     8435840            1      4      1     10
# 68578  20251148   11  2025     8435840            1      5      1     10
# 68579  20251148   11  2025     8435840            1      6      1     10
# 68580  20251148   11  2025     8435840            1      7      1     10
# 68581  20251148   11  2025     8435840            1      8      1     10
#
#        AREA  CLASE  FEX_C18  DPTO  PT  P6016  P3271  P6040  P6030S1  P6030S3  \
# ...

# %%
print(df_noviembre.shape)
print(df_noviembre.columns)
# Out:
# (68582, 348)
# Index(['PERIODO', 'MES', 'PER', 'DIRECTORIO', 'SECUENCIA_P', 'ORDEN', 'HOGAR',
#        'REGIS', 'AREA', 'CLASE',
#        ...
#        'P1881', 'P1881S1', 'P1882', 'P7240', 'P7240S1', 'OCI', 'INGLABO',
#        'RAMA2D_R4', 'RAMA4D_R4', 'OFICIO_C8'],
#       dtype='object', length=348)

# %% [markdown]
# ##**Mes Diciembre**

# %%
df_GEIH_diciembre_caracteristicas = pd.read_csv("/content/drive/MyDrive/IA Economia/Taller importación, combinación y exportación de datos/GEIH 2025 (julio,diciembre)/Diciembre 2025/CSV/Características generales, seguridad social en salud y educación.CSV", sep = ";")

# %%
df_GEIH_diciembre_hogar = pd.read_csv("/content/drive/MyDrive/IA Economia/Taller importación, combinación y exportación de datos/GEIH 2025 (julio,diciembre)/Diciembre 2025/CSV/Datos del hogar y la vivienda.CSV", sep= ";", encoding="latin1")

# %%
df_GEIH_diciembre_fuerza = pd.read_csv("/content/drive/MyDrive/IA Economia/Taller importación, combinación y exportación de datos/GEIH 2025 (julio,diciembre)/Diciembre 2025/CSV/Fuerza de trabajo.CSV", sep=";", encoding='latin1')
# Out:
# /tmp/ipykernel_849/2399789708.py:1: DtypeWarning: Columns (33) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_GEIH_diciembre_fuerza = pd.read_csv("/content/drive/MyDrive/IA Economia/Taller importación, combinación y exportación de datos/GEIH 2025 (julio,diciembre)/Diciembre 2025/CSV/Fuerza de trabajo.CSV", sep=";", encoding='latin1')

# %%
df_GEIH_diciembre_ocupados = pd.read_csv("/content/drive/MyDrive/IA Economia/Taller importación, combinación y exportación de datos/GEIH 2025 (julio,diciembre)/Diciembre 2025/CSV/Ocupados.CSV", sep=";", encoding='latin1')
# Out:
# /tmp/ipykernel_849/1347786832.py:1: DtypeWarning: Columns (28,89,133) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_GEIH_diciembre_ocupados = pd.read_csv("/content/drive/MyDrive/IA Economia/Taller importación, combinación y exportación de datos/GEIH 2025 (julio,diciembre)/Diciembre 2025/CSV/Ocupados.CSV", sep=";", encoding='latin1')

# %%
df_diciembre= pd.concat([df_GEIH_diciembre_caracteristicas,df_GEIH_diciembre_hogar,df_GEIH_diciembre_fuerza,df_GEIH_diciembre_ocupados], axis= 1,)
df_diciembre
# Out:
#         PERIODO  MES   PER  DIRECTORIO  SECUENCIA_P  ORDEN  HOGAR  REGIS  \
# 0      20251252   12  2025     8435963            1      1      1     10
# 1      20251252   12  2025     8435963            1      2      1     10
# 2      20251252   12  2025     8435963            1      3      1     10
# 3      20251252   12  2025     8435964            1      1      1     10
# 4      20251252   12  2025     8435965            1      1      1     10
# ...         ...  ...   ...         ...          ...    ...    ...    ...
# 66554  20251252   12  2025     8473907            1      1      1     10
# 66555  20251252   12  2025     8473908            1      1      1     10
# 66556  20251252   12  2025     8473908            1      2      1     10
# 66557  20251252   12  2025     8473908            1      3      1     10
# 66558  20251252   12  2025     8473908            1      4      1     10
#
#        AREA  CLASE  FEX_C18  DPTO  PT  P6016  P3271  P6040  P6030S1  P6030S3  \
# ...

# %%
print(df_diciembre.shape)
print(df_diciembre.columns)
# Out:
# (66559, 348)
# Index(['PERIODO', 'MES', 'PER', 'DIRECTORIO', 'SECUENCIA_P', 'ORDEN', 'HOGAR',
#        'REGIS', 'AREA', 'CLASE',
#        ...
#        'P1881', 'P1881S1', 'P1882', 'P7240', 'P7240S1', 'OCI', 'INGLABO',
#        'RAMA2D_R4', 'RAMA4D_R4', 'OFICIO_C8'],
#       dtype='object', length=348)

# %% [markdown]
# ##**Base 2025**

# %%
df_junio = df_junio.loc[:,~df_junio.columns.duplicated()]
df_julio = df_julio.loc[:,~df_julio.columns.duplicated()]
df_agosto = df_agosto.loc[:,~df_agosto.columns.duplicated()]
df_septiembre = df_septiembre.loc[:,~df_septiembre.columns.duplicated()]
df_octubre = df_octubre.loc[:,~df_octubre.columns.duplicated()]
df_noviembre = df_noviembre.loc[:,~df_noviembre.columns.duplicated()]
df_diciembre = df_diciembre.loc[:,~df_diciembre.columns.duplicated()]
df_GEIH_2025 = pd.concat([df_junio,df_julio,df_agosto,df_septiembre,df_octubre,df_noviembre,df_diciembre], axis=0, ignore_index=True)
df_GEIH_2025
# Out:
#          PERIODO  MES   PER  DIRECTORIO  SECUENCIA_P  ORDEN  HOGAR  REGIS  \
# 0       20250626    6  2025     8238974            1      1      1     10
# 1       20250626    6  2025     8238974            1      2      1     10
# 2       20250626    6  2025     8238975            1      1      1     10
# 3       20250626    6  2025     8238975            1      2      1     10
# 4       20250626    6  2025     8238975            1      3      1     10
# ...          ...  ...   ...         ...          ...    ...    ...    ...
# 476978  20251252   12  2025     8473907            1      1      1     10
# 476979  20251252   12  2025     8473908            1      1      1     10
# 476980  20251252   12  2025     8473908            1      2      1     10
# 476981  20251252   12  2025     8473908            1      3      1     10
# 476982  20251252   12  2025     8473908            1      4      1     10
#
#         AREA  CLASE  FEX_C18  DPTO  PT  P6016  P3271  P6040  P6030S1  P6030S3  \
# ...

# %%
print(df_GEIH_2025.shape)
print(df_GEIH_2025.columns)
# Out:
# (476983, 312)
# Index(['PERIODO', 'MES', 'PER', 'DIRECTORIO', 'SECUENCIA_P', 'ORDEN', 'HOGAR',
#        'REGIS', 'AREA', 'CLASE',
#        ...
#        'P1881', 'P1881S1', 'P1882', 'P7240', 'P7240S1', 'OCI', 'INGLABO',
#        'RAMA2D_R4', 'RAMA4D_R4', 'OFICIO_C8'],
#       dtype='object', length=312)

# %% [markdown]
# ##**Columna RAMA4D_R4**

# %%
df_GEIH_2025.columns
# Out:
# Index(['PERIODO', 'MES', 'PER', 'DIRECTORIO', 'SECUENCIA_P', 'ORDEN', 'HOGAR',
#        'REGIS', 'AREA', 'CLASE',
#        ...
#        'P1881', 'P1881S1', 'P1882', 'P7240', 'P7240S1', 'OCI', 'INGLABO',
#        'RAMA2D_R4', 'RAMA4D_R4', 'OFICIO_C8'],
#       dtype='object', length=312)

# %%
CIIU = pd.read_excel("/content/drive/MyDrive/IA Economia/Taller importación, combinación y exportación de datos/Estructura-detallada-CIIU-4AC-2022.xlsx", header=1)
CIIU
# Out:
#       División  Grupo    Clase  \
# 0    SECCIÓN A    NaN      NaN
# 1           01    NaN      NaN
# 2          NaN  11.00      NaN
# 3          NaN    NaN   111.00
# 4          NaN    NaN   112.00
# ..         ...    ...      ...
# 716        NaN 981.00 9,810.00
# 717        NaN 982.00 9,820.00
# 718  SECCIÓN U    NaN      NaN
# 719         99    NaN      NaN
# 720        NaN 990.00 9,900.00
#
#                                            Descripción
# 0    AGRICULTURA, GANADERÍA, CAZA, SILVICULTURA Y P...
# 1    Agricultura, ganadería, caza y actividades de ...
# 2                      Cultivos agrícolas transitorios
# 3    Cultivo de cereales (excepto arroz), legumbres...
# 4                                     Cultivo de arroz
# ..                                                 ...
# 716  Actividades no diferenciadas de los hogares in...
# 717  Actividades no diferenciadas de los hogares in...
# 718  ACTIVIDADES DE ORGANIZACIONES Y ENTIDADES EXTR...
# ...

# %%
CIIU = CIIU[["Clase", "Descripción"]]

# %%
CIIU = CIIU.drop_duplicates(subset= "Clase")

# %%
CIIU.shape
# Out:
# (503, 2)

# %%
df_GEIH_2025["RAMA4D_R4"] = df_GEIH_2025["RAMA4D_R4"].astype(float)
CIIU['Clase']= CIIU['Clase'].astype(float)

# %%
df_GEIH_2025 = df_GEIH_2025.merge(
    CIIU,
    left_on="RAMA4D_R4",
    right_on="Clase",
    how="left")

# %%
df_GEIH_2025 = df_GEIH_2025.drop(columns=["Clase"])

# %%
df_GEIH_2025[["RAMA4D_R4","Descripción"]].head()
# Out:
#    RAMA4D_R4                                 Descripción
# 0     113.00  Cultivo de hortalizas, raíces y tubérculos
# 1     113.00  Cultivo de hortalizas, raíces y tubérculos
# 2     113.00  Cultivo de hortalizas, raíces y tubérculos
# 3     145.00                      Cría de aves de corral
# 4     122.00                 Cultivo de plátano y banano

# %%
df_GEIH_2025.shape
# Out:
# (476983, 313)

# %% [markdown]
# ##**Divipola**

# %%
DIVIPOLA = pd.read_excel("/content/drive/MyDrive/IA Economia/Taller importación, combinación y exportación de datos/DIVIPOLA_Departamentos.xlsx", header=None)

# %%
DIVIPOLA.head(15)
# Out:
#                                                     0             1        2  \
# 0                                                 NaN           NaN      NaN
# 1                                                 NaN           NaN      NaN
# 2                                                 NaN           NaN      NaN
# 3                                                 NaN           NaN      NaN
# 4                                                 NaN           NaN      NaN
# 5   Codificación de la División Político Administr...           NaN      NaN
# 6                                                 NaN           NaN      NaN
# 7                                       Departamentos           NaN      NaN
# 8                                                 NaN           NaN      NaN
# 9                                              Código        Nombre  LATITUD
# 10                                                 05     ANTIOQUIA     6.70
# ...

# %%
DIVIPOLA = pd.read_excel("/content/drive/MyDrive/IA Economia/Taller importación, combinación y exportación de datos/DIVIPOLA_Departamentos.xlsx", header=9, skipfooter=1)

# %%
DIVIPOLA.columns
# Out:
# Index(['Código', 'Nombre', 'LATITUD', 'LONGITUD'], dtype='object')

# %%
DIVIPOLA = DIVIPOLA[["Código", "Nombre"]]

# %%
DIVIPOLA = DIVIPOLA.drop_duplicates()

# %%
DIVIPOLA["Código"] = pd.to_numeric(DIVIPOLA["Código"], errors="coerce")

# %%
DIVIPOLA = DIVIPOLA.dropna(subset=["Código"])

# %%
DIVIPOLA["Código"] = DIVIPOLA["Código"].astype(float)

# %%
df_GEIH_2025["DPTO"] = df_GEIH_2025["DPTO"].astype(float)

df_GEIH_2025 = df_GEIH_2025.merge(
    DIVIPOLA,
    left_on="DPTO",
    right_on="Código",
    how="left")

# %%
df_GEIH_2025 = df_GEIH_2025.drop(columns=["Código"])

# %%
df_GEIH_2025[["DPTO","Nombre"]].head()
# Out:
#    DPTO     Nombre
# 0  8.00  ATLÁNTICO
# 1  8.00  ATLÁNTICO
# 2  8.00  ATLÁNTICO
# 3  8.00  ATLÁNTICO
# 4  8.00  ATLÁNTICO

# %% [markdown]
# ##**Guardar base de datos**

# %%
df_GEIH_2025.shape
# Out:
# (476983, 314)

# %%
df_GEIH_2025.columns
# Out:
# Index(['PERIODO', 'MES', 'PER', 'DIRECTORIO', 'SECUENCIA_P', 'ORDEN', 'HOGAR',
#        'REGIS', 'AREA', 'CLASE',
#        ...
#        'P1882', 'P7240', 'P7240S1', 'OCI', 'INGLABO', 'RAMA2D_R4', 'RAMA4D_R4',
#        'OFICIO_C8', 'Descripción', 'Nombre'],
#       dtype='object', length=314)

# %%
df_GEIH_2025
# Out:
#          PERIODO  MES   PER  DIRECTORIO  SECUENCIA_P  ORDEN  HOGAR  REGIS  \
# 0       20250626    6  2025     8238974            1      1      1     10
# 1       20250626    6  2025     8238974            1      2      1     10
# 2       20250626    6  2025     8238975            1      1      1     10
# 3       20250626    6  2025     8238975            1      2      1     10
# 4       20250626    6  2025     8238975            1      3      1     10
# ...          ...  ...   ...         ...          ...    ...    ...    ...
# 476978  20251252   12  2025     8473907            1      1      1     10
# 476979  20251252   12  2025     8473908            1      1      1     10
# 476980  20251252   12  2025     8473908            1      2      1     10
# 476981  20251252   12  2025     8473908            1      3      1     10
# 476982  20251252   12  2025     8473908            1      4      1     10
#
#         AREA  CLASE  FEX_C18  DPTO  PT  P6016  P3271  P6040  P6030S1  P6030S3  \
# ...

# %%
df_GEIH_2025.to_csv("/content/drive/MyDrive/IA Economia/GEIH_2025.csv", index=False)
