# %% [markdown]
# <a href="https://colab.research.google.com/github/juanjosedelgado-coder/Talleres/blob/main/Taller_Diccionarios_Juan_Natalia_Delgado_Vargas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a href="https://colab.research.google.com/github/LinaMariaCastro/curso-ia-para-economia/blob/main/clases/2_Programacion_en_Python/10_Taller_Diccionarios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Inteligencia Artificial con Aplicaciones en Economía I**
#
# - 👩‍🏫 **Profesora:** [Lina María Castro](https://www.linkedin.com/in/lina-maria-castro)
# - 📧 **Email:** [lmcastroco@gmail.com](mailto:lmcastroco@gmail.com)
# - 🎓 **Universidad:** Universidad Externado de Colombia - Facultad de Economía

# %% [markdown]
# # Taller Programación en Python: Diccionarios, range y operadores
# ---

# %% [markdown]
# **IMPORTANTE**: Guarda una copia de este notebook en tu Google Drive o computador.

# %% [markdown]
# **Taller en parejas**

# %% [markdown]
# **Nombres estudiantes:**
#
# - Juan Jose Delgado
# - Natalia Vargas

# %% [markdown]
# **Forma de entrega:**
#
# - Registrar las respuestas en https://forms.office.com/r/jNMe8MLbjf para obtener la calificación. Vale 20 puntos.
#
# - Publicar Jupyter Notebook con el desarrollo del taller en la cuenta de Github de uno de los estudiantes. Nombrar el archivo de la siguiente forma:“Taller_Diccionarios_nombres_y_appellidos.ipynb”. Esto vale 5 puntos adicionales a las respuestas del formulario.
#
# Puntaje total del taller: 25 puntos.

# %% [markdown]
# **Plazo de entrega:**
#
# 12 de febrero de 2026, máximo a las 11:59 p.m. Tenga en cuenta que luego de esa hora el formulario en forms se cierra. El Jupupyter Notebook también debe quedar subido en Github antes de esa hora.

# %% [markdown]
# **Instrucciones Generales:**
#
# Completa el código en las celdas marcadas con `### TU CÓDIGO AQUÍ ###`. Puedes añadir más celdas si lo requieres.

# %% [markdown]
# **Contexto:**
#
# Has sido contratado por la *Unidad de Análisis Macroeconómico* de un banco para automatizar el procesamiento de carteras de crédito y reportes de indicadores económicos nacionales.

# %% [markdown]
# ### **Ejercicio 1: Registro de Deudores**
# Crea un diccionario llamado `deudor_1` que contenga:
# - `nombre`: "Carlos Restrepo"
# - `ingresos`: 4500
# - `score_crediticio`: 720

# %%
### TU CÓDIGO AQUÍ ###
deudor_1 = {"nombre": "Carlos Restrepo", "ingresos": 4500, "score_crediticio": 720}
print(deudor_1)
# Out:
# {'nombre': 'Carlos Restrepo', 'ingresos': 4500, 'score_crediticio': 720}

# %% [markdown]
# ### **Ejercicio 2: Consulta de Información**
# Extrae el valor del `score_crediticio` del cliente Carlos Restrepo y almacénalo en una variable llamada `puntaje`.

# %%
### TU CÓDIGO AQUÍ ###
puntaje = deudor_1["score_crediticio"]
print(f"El puntaje es: {puntaje}")
# Out:
# El puntaje es: 720

# %% [markdown]
# ### **Ejercicio 3: Actualización de Datos**
# Debido a una actualización salarial, cambia los ingresos del cliente Carlos Restrepo a 5200.

# %%
### TU CÓDIGO AQUÍ ###
deudor_1["ingresos"] = 5200
print(deudor_1)
# Out:
# {'nombre': 'Carlos Restrepo', 'ingresos': 5200, 'score_crediticio': 720}

# %% [markdown]
# ### **Ejercicio 4: Evaluación de Riesgo**
# Crea una variable booleana `es_aprobado` que sea `True` si el score del cliente Carlos Restrepo es mayor o igual a 700 y sus ingresos son superiores a 5000.

# %%
### TU CÓDIGO AQUÍ ###
es_aprobado = deudor_1["score_crediticio"] >700 and deudor_1["ingresos"] > 5000
print(f"¿Aprobado?: {es_aprobado}")
# Out:
# ¿Aprobado?: True

# %% [markdown]
# ### **Ejercicio 5: Validación**
# Verifica si la variable `es_aprobado` es estrictamente igual a `True` usando el operador `is`. Guarda el resultado en la variable `check`.

# %%
### TU CÓDIGO AQUÍ ###
check = es_aprobado is True
print(check)
# Out:
# True

# %% [markdown]
# ### **Ejercicio 6: Agregar Información**
# En el diccionario que almacena los datos del cliente Carlos Restrepo, agrega una nueva llave `ciudad` con el valor "Medellín" .

# %%
### TU CÓDIGO AQUÍ ###
deudor_1["ciudad"] = "Medellín"
print(deudor_1)
# Out:
# {'nombre': 'Carlos Restrepo', 'ingresos': 5200, 'score_crediticio': 720, 'ciudad': 'Medellín'}

# %% [markdown]
# ### **Ejercicio 7: Borrado de Datos Sensibles**
# En el diccionario que almacena los datos del cliente Carlos Restrepo, elimina la información de `score_crediticio`. Usa el método `.pop()`.

# %%
### TU CÓDIGO AQUÍ ###
deudor_1.pop("score_crediticio")
print(deudor_1)
# Out:
# {'nombre': 'Carlos Restrepo', 'ingresos': 5200, 'ciudad': 'Medellín'}

# %% [markdown]
# ### **Ejercicio 8: Validación**
# Verifica si en los datos del cliente Carlos Restrepo hay información de sus ingresos. Guarda el resultado booleano en `existe_ingresos`.

# %%
### TU CÓDIGO AQUÍ ###
existe_ingresos = "ingresos" in deudor_1
print(existe_ingresos)
# Out:
# True

# %% [markdown]
# ### **Ejercicio 9: Validación**
# Usa el método `.get()` para buscar la llave `"tasa_cambio"` en el diccionario que contiene los datos del cliente Carlos Restrepo. Si no existe, que retorne el valor `4000`. Guarda el resultado en una variable llamada `trm`.

# %%
### TU CÓDIGO AQUÍ ###
trm = deudor_1.get("tasa_cambio", 4000)
print(trm)
# Out:
# 4000

# %% [markdown]
# ### **Ejercicio 10: Agregar Información**
# Actualiza los datos del cliente Carlos Restrepo agregando al diccionario `{"estrato": 4}`. Usa el método `.update()`.

# %%
### TU CÓDIGO AQUÍ ###
deudor_1.update({"estrato": 4})
print(deudor_1)
# Out:
# {'nombre': 'Carlos Restrepo', 'ingresos': 5200, 'ciudad': 'Medellín', 'estrato': 4}

# %% [markdown]
# ### **Ejercicio 11: Portafolio**
# Crea un diccionario `cartera_bancaria` donde las llaves sean los sectores en los que el banco ofrece préstamos: `"Agro"`, `"Industria"` y `"Vivienda"`, y los valores sean listas con 3 montos de crédito para cada sector, así:
# - Montos de crédito para Agro: 100, 200 y 150
# - Montos de crédito para Industria: 500, 450 y 600
# - Montos de crédito para Vivienda: 300, 320 y 280

# %%
### TU CÓDIGO AQUÍ ###
cartera_bancaria= {"Agro":[100,200,150], "Industria": [500,450,600], "Vivienda": [300,320,380]}
print(cartera_bancaria)
# Out:
# {'Agro': [100, 200, 150], 'Industria': [500, 450, 600], 'Vivienda': [300, 320, 380]}

# %% [markdown]
# ### **Ejercicio 12: Acceso a un Monto de Crédito Específico**
# Extrae el segundo monto del sector `"Industria"` en una variable llamada `monto_especifico`.

# %%
### TU CÓDIGO AQUÍ ###
monto_especifico = cartera_bancaria["Industria"][1]
print(monto_especifico)
# Out:
# 450

# %% [markdown]
# ### **Ejercicio 13: Identificación de Sectores**
# Obtén una lista de todos los sectores disponibles en `cartera_bancaria` y guárdala en la variable `sectores`.

# %%
### TU CÓDIGO AQUÍ ###
sectores= list(cartera_bancaria.keys())
print(sectores)
# Out:
# ['Agro', 'Industria', 'Vivienda']

# %% [markdown]
# ### **Ejercicio 14: Conteo de Cartera**
# Cuenta cuántos sectores hay en `cartera_bancaria` y guárdalo en `n_sectores`.

# %%
### TU CÓDIGO AQUÍ ###
n_sectores = len(cartera_bancaria)
print(n_sectores)
# Out:
# 3

# %% [markdown]
# ### **Ejercicio 15: Rango de Años para el IPC**
# Crea una lista llamada `periodo_analisis` que contenga los años desde 2015 hasta 2024 (inclusive).

# %%
### TU CÓDIGO AQUÍ ###
periodo_analisis = list(range(2015,2025))
print(periodo_analisis)
# Out:
# [2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024]

# %% [markdown]
# ### **Ejercicio 16: Ciclo Político**
# Genera una lista con los años en que ha habido elecciones presidenciales en Colombia (cada 4 años) desde 1994 hasta 2026 (inclusive). Guárdalo en una variable llamada `años_elecciones`.

# %%
### TU CÓDIGO AQUÍ ###
años_elecciones = list(range(1994,2027,4))
print(años_elecciones)
# Out:
# [1994, 1998, 2002, 2006, 2010, 2014, 2018, 2022, 2026]

# %% [markdown]
# ### **Ejercicio 17: Información del DANE**
# Crea un diccionario llamado `hogar_dane` que contenga el id del hogar y la cantidad de miembros que son adultos y que son niños, así:
# - `id`: 101
# - `miembros`: un diccionario con las llaves "Adultos" (cuyo valor es 2) y "Niños" (cuyo valor es 1).

# %%
### TU CÓDIGO AQUÍ ###
hogar_dane = {"id": 101, "miembros": {"Adultos": 2, "Niños":1}}
print(hogar_dane)
# Out:
# {'id': 101, 'miembros': {'Adultos': 2, 'Niños': 1}}

# %% [markdown]
# ### **Ejercicio 18: Comparación de Inflación**
# Si `inf_2023 = 9.28` e `inf_2022 = 13.12`, crea una variable `hubo_descenso` que sea `True` si la inflación de 2023 fue menor a la de 2022.

# %%
### TU CÓDIGO AQUÍ ###
inf_2023 = 9.28
inf_2022 = 13.12
hubo_descenso = inf_2023 < inf_2022
print(hubo_descenso)
# Out:
# True

# %% [markdown]
# ### **Ejercicio 19: Construcción de Información Macroeconómica**
# Dadas las listas `k = ["PIB", "IPC"]` y `v = [1.2, 0.5]`. Crea un diccionario `indicadores` uniendo ambas listas.

# %%
### TU CÓDIGO AQUÍ ###
k= ["PIB", "IPC"]
v = [1.2, 0.5]
indicadores= dict(zip(k,v))
print(indicadores)
# Out:
# {'PIB': 1.2, 'IPC': 0.5}

# %% [markdown]
# ### **Ejercicio 20: Vaciado de Información**
# Limpia todo el contenido del diccionario `indicadores` dejándolo vacío con el método `.clear()`.

# %%
### TU CÓDIGO AQUÍ ###
indicadores.clear()
print(indicadores)
# Out:
# {}

# %% [markdown]
# Ejecuta esta celda al finalizar todo el taller. Si no obtienes ningún error, ¡felicidades! Tu lógica es correcta. Si obtienes un mensaje de error en la validación, revisa los puntos indicados.

# %%
def verificar_taller():
    errores = []

    try:
        if not (isinstance(deudor_1, dict) and "Carlos Restrepo" in deudor_1.values()):
            errores.append("1")
        if not ((puntaje * 2) / 10 == 144.0):
            errores.append("2")
        if not (deudor_1.get("ingresos") == 2600*2 and deudor_1["ingresos"] + 800 == 6000):
            errores.append("3")
        if not (es_aprobado is True):
            errores.append("4")
        if not (check is True):
            errores.append("19")
        if not (deudor_1.get("ciudad") == "Medellín" and len(deudor_1) >= 42/14):
            errores.append("5")
        if not ("score_crediticio" not in deudor_1):
            errores.append("12")
        if not (existe_ingresos is True):
            errores.append("13")
        if not ((trm ** 0.5) == 63.245553203367585):
            errores.append("17")
        if not (deudor_1.get("estrato") == 64/16 and "categoria" not in deudor_1):
             if not (deudor_1.get("estrato") == 64/16):
                errores.append("20")
        if not (len(cartera_bancaria) == 24/8 and isinstance(cartera_bancaria["Agro"], list)):
            errores.append("6")
        if not ((monto_especifico / 3) == 150):
            errores.append("7")
        if not (len(sectores) == 27/9 and "Vivienda" in sectores):
            errores.append("8")
        if not (n_sectores == 3):
            errores.append("18")
        if not (len(periodo_analisis) == 2.5*4 and sum(periodo_analisis) == 20195):
            errores.append("9")
        if not (len(años_elecciones) == 72/8 and años_elecciones[-1] == 2026):
            errores.append("10")
        if not (isinstance(hogar_dane["miembros"], dict) and hogar_dane["miembros"].get("Niños") == 1):
            errores.append("11")
        if not (hubo_descenso is True):
            errores.append("14")
        if not (isinstance(indicadores, dict)):
            errores.append("15")
        if not (len(indicadores) == 0 and isinstance(indicadores, dict)):
            errores.append("16")

    except NameError as e:
        errores.append(f"Variable no definida: {e}")
    except Exception as e:
        errores.append(f"Error de ejecución: {str(e)}")

    if not errores:
        print("✅ ¡Felicidades! El reporte de consultoría es impecable. Todos los ejercicios son correctos.")
    else:
        solo_numeros = [err for err in errores if err.isdigit()]
        errores_var = [err for err in errores if not err.isdigit()]
        mensaje_final = f"❌ Se encontraron inconsistencias en los siguientes ejercicios: {', '.join(solo_numeros)}"
        print(mensaje_final)
        if errores_var:
            print(f"{errores_var[0]}")
        print("\nRevisa la lógica de los diccionarios, los límites de los range o los operadores lógicos e intenta de nuevo.")

verificar_taller()
# Out:
# ✅ ¡Felicidades! El reporte de consultoría es impecable. Todos los ejercicios son correctos.
