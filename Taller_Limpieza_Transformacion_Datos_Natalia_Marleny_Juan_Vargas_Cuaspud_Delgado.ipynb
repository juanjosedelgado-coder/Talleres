# %% [markdown]
# <a href="https://colab.research.google.com/github/juanjosedelgado-coder/Talleres/blob/main/Taller_Limpieza_Transformacion_Datos_Natalia_Marleny_Juan_Vargas_Cuaspud_Delgado.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Inteligencia Artificial con Aplicaciones en Economía I**
#
# - 👩‍🏫 **Profesora:** [Lina María Castro](https://www.linkedin.com/in/lina-maria-castro)
# - 📧 **Email:** [lmcastroco@gmail.com](mailto:lmcastroco@gmail.com)
# - 🎓 **Universidad:** Universidad Externado de Colombia - Facultad de Economía

# %% [markdown]
# # **Taller Limpieza y transformación de datos**🧹

# %% [markdown]
# **IMPORTANTE**: Guarda una copia de este notebook en tu Google Drive o computador.

# %% [markdown]
# **Taller en grupos de 3 o parejas.**

# %% [markdown]
# **Nombres estudiantes:**
#
# - Natalia Vargas
# - Marleny Cuaspud
# - Juan Jose Delgado

# %% [markdown]
# **Forma de entrega:**
#
# - Nombrar el archivo de la siguiente forma:“Taller_Limpieza_nombres_y_appellidos.ipynb”.
# - Suba el Jupyter Notebook a su cuenta en Github y envíe el link en el siguiente Forms: https://forms.office.com/r/6GZ89uiLNC.
#
# **IMPORTANTE:** No se recibirán talleres en Google Colab, el notebook debe estar subido en Github.

# %% [markdown]
# **Plazo de entrega:**
#
# 19 de marzo de 2026, máximo a las 11:59 p.m. Tenga en cuenta que luego de esa hora el formulario en forms se cierra. El Jupupyter Notebook también debe quedar subido en Github antes de esa hora.

# %% [markdown]
# **Instrucciones Generales:**
#
# Completa el código en las celdas marcadas con `### TU CÓDIGO AQUÍ ###`. Puedes añadir más celdas si lo requieres.

# %% [markdown]
# Utilice la base de la GEIH de julio a diciembre de 2025, la cual se encuentra en https://drive.google.com/drive/folders/1Th4TWdsOahAAvBUKxixFhaELC_KPsl3y?usp=sharing. Tenga en cuenta sep="," y encoding='latin1'. Las variables 'DPTO' y 'RAMA4D_R4' deben ser cargadas como string.

# %% [markdown]
# # Ejercicio 1: Importar librerías y cargar datos

# %% [markdown]
# 1.	Importe todas las librerías que vaya a utilizar.

# %%
import pandas as pd
import numpy as np
import os
import warnings

# %% [markdown]
# 2.	Mejore la visualización de los dataframes como se ha visto en clase.

# %%
# Que muestre todas las columnas
pd.options.display.max_columns = None
# En los dataframes, mostrar los float con dos decimales
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# 3.	Conéctese a su Google Drive y establezca la ruta del dataset.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# 4.	Cargue los datos en el notebook. Llame al dataframe 'df_geih'

# %%
### TU CÓDIGO AQUÍ ###
df_geih = pd.read_csv("/content/drive/MyDrive/IA Economia/GEIH_2025_Jul_Dic_Consolidado.csv", encoding="latin1")
# Out:
# /tmp/ipykernel_231/2801498885.py:2: DtypeWarning: Columns (74,89,102,110,116,137,204,254,257,261,263,266,268,277,298,306) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_geih = pd.read_csv("/content/drive/MyDrive/IA Economia/GEIH_2025_Jul_Dic_Consolidado.csv", encoding="latin1")

# %% [markdown]
# 5. Obtenga las dimensiones de la base

# %%
### TU CÓDIGO AQUÍ ###
df_geih.shape
# Out:
# (409127, 314)

# %% [markdown]
# # Ejercicio 2:  Seleccionar y renombrar columnas

# %% [markdown]
# La GEIH contiene cientos de variables. Para nuestro análisis del mercado laboral, nos enfocaremos en un subconjunto.
#
# Adicionalmente, los nombres de las columnas en la GEIH son códigos. Para hacer el análisis más intuitivo, vamos a renombrarlas.

# %% [markdown]
# 1. Crea un nuevo DataFrame llamado `df_empleo` que contenga únicamente las columnas que están en la lista `columnas_interes`.

# %%
columnas_interes = ['DIRECTORIO', 'SECUENCIA_P', 'ORDEN', 'MES', 'CLASE', 'DPTO', 'FEX_C18', 'PT', 'P3271', 'P6040', 'P6080', 'P3043', 'OCI',
                    'P6430', 'RAMA4D_R4', 'INGLABO', 'DESCRIPCION_CIIU', 'NOMBRE_DPTO']

# %%
### TU CÓDIGO AQUÍ ###
df_empleo = df_geih[columnas_interes]
df_empleo.head()
# Out:
#    DIRECTORIO  SECUENCIA_P  ORDEN  MES  CLASE  DPTO  FEX_C18  PT  P3271  \
# 0     8283143            1      1    7      2     8    27.75   1      1
# 1     8283143            1      2    7      2     8    27.75   1      2
# 2     8283145            1      1    7      2     8    59.11   1      1
# 3     8283145            1      2    7      2     8    59.11   1      2
# 4     8283145            1      3    7      2     8    59.11   1      1
#
#    P6040  P6080  P3043  OCI  P6430  RAMA4D_R4      INGLABO  \
# 0     72      6    NaN 1.00   7.00     143.00   790,000.00
# 1     34      6    NaN  NaN    NaN        NaN          NaN
# 2     45      6    NaN 1.00   1.00     141.00 1,100,000.00
# 3     50      6    NaN  NaN    NaN        NaN          NaN
# 4     19      6    NaN 1.00   7.00     141.00   820,000.00
#
#                    DESCRIPCION_CIIU NOMBRE_DPTO
# 0           Cría de ovejas y cabras   ATLÁNTICO
# 1                               NaN   ATLÁNTICO
# 2  Cría de ganado bovino y bufalino   ATLÁNTICO
# 3                               NaN   ATLÁNTICO
# 4  Cría de ganado bovino y bufalino   ATLÁNTICO

# %% [markdown]
# 2. Renombra las columnas del DataFrame `df_empleo` utilizando el diccionario `mapa_nombres`.

# %%
mapa_nombres = {
'DIRECTORIO': 'id_vivienda',
'SECUENCIA_P': 'id_hogar',
'ORDEN': 'id_persona',
'MES': 'mes',
'CLASE': 'clase',
'DPTO': 'departamento',
'FEX_C18': 'factor_expansion',
'PT': 'poblacion_total',
'P3271': 'sexo',
'P6040': 'edad',
'P6080': 'grupo_etnico',
'P3043': 'nivel_educativo',
'OCI': 'ocupados',
'P6430': 'categoria_ocupacional',
'RAMA4D_R4': 'cod_ciiu',
'INGLABO': 'ingreso_laboral',
'DESCRIPCION_CIIU': 'desc_ciiu',
'NOMBRE_DPTO': 'nombre_dpto'}

# %%
### TU CÓDIGO AQUÍ ###
df_empleo.rename(columns=mapa_nombres, inplace=True)
df_empleo.head()
# Out:
# /tmp/ipykernel_231/3096020858.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_empleo.rename(columns=mapa_nombres, inplace=True)
#    id_vivienda  id_hogar  id_persona  mes  clase  departamento  \
# 0      8283143         1           1    7      2             8
# 1      8283143         1           2    7      2             8
# 2      8283145         1           1    7      2             8
# 3      8283145         1           2    7      2             8
# 4      8283145         1           3    7      2             8
#
#    factor_expansion  poblacion_total  sexo  edad  grupo_etnico  \
# 0             27.75                1     1    72             6
# 1             27.75                1     2    34             6
# 2             59.11                1     1    45             6
# 3             59.11                1     2    50             6
# 4             59.11                1     1    19             6
#
#    nivel_educativo  ocupados  categoria_ocupacional  cod_ciiu  \
# 0              NaN      1.00                   7.00    143.00
# 1              NaN       NaN                    NaN       NaN
# 2              NaN      1.00                   1.00    141.00
# 3              NaN       NaN                    NaN       NaN
# 4              NaN      1.00                   7.00    141.00
#
#    ingreso_laboral                         desc_ciiu nombre_dpto
# 0       790,000.00           Cría de ovejas y cabras   ATLÁNTICO
# 1              NaN                               NaN   ATLÁNTICO
# 2     1,100,000.00  Cría de ganado bovino y bufalino   ATLÁNTICO
# 3              NaN                               NaN   ATLÁNTICO
# 4       820,000.00  Cría de ganado bovino y bufalino   ATLÁNTICO

# %% [markdown]
# 3. Obtenga las dimensiones de la base

# %%
### TU CÓDIGO AQUÍ ###
df_empleo.shape
# Out:
# (409127, 18)

# %% [markdown]
# # Ejercicio 3: Revisión de duplicados

# %% [markdown]
# Un paso crucial en la limpieza es asegurar que no haya observaciones duplicadas que puedan sesgar nuestro análisis.

# %% [markdown]
# 1. Verifica si hay filas duplicadas en `df_empleo`.

# %%
### TU CÓDIGO AQUÍ ###
df_empleo.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# 2. Cuenta cuántas filas duplicadas existen.

# %%
### TU CÓDIGO AQUÍ ###
df_empleo.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# 3. Elimina las filas duplicadas, si las hay.

# %%
### TU CÓDIGO AQUÍ ###
df_empleo = df_empleo.drop_duplicates()

# %% [markdown]
# 4. Verifica si hay filas duplicadas específicamente en las columnas 'id_vivienda', 'id_hogar', 'id_persona'.

# %%
### TU CÓDIGO AQUÍ ###
df_empleo.duplicated(subset=['id_vivienda', 'id_hogar', 'id_persona']).sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Ejercicio 4: Valores faltantes

# %% [markdown]
# Los datos del mundo real raramente están completos. Aquí, trataremos los valores faltantes en la columna de ingresos.

# %% [markdown]
# 1. Calcula el número de valores nulos (`NaN`) en la columna `ingreso_laboral` **antes** de cualquier modificación.

# %%
### TU CÓDIGO AQUÍ ###
df_empleo['ingreso_laboral'].isna().sum()
# Out:
# np.int64(231144)

# %% [markdown]
# 2. En la GEIH, un ingreso faltante a menudo significa que la persona no reportó ingresos o no aplica (ej. no trabaja). Una estrategia común es imputar estos valores con `0`. Rellena los valores `NaN` en la columna `ingreso_laboral` con `0`.

# %%
### TU CÓDIGO AQUÍ ###
df_empleo['ingreso_laboral'] = df_empleo['ingreso_laboral'].fillna(0)
df_empleo
# Out:
#         id_vivienda  id_hogar  id_persona  mes  clase  departamento  \
# 0           8283143         1           1    7      2             8
# 1           8283143         1           2    7      2             8
# 2           8283145         1           1    7      2             8
# 3           8283145         1           2    7      2             8
# 4           8283145         1           3    7      2             8
# ...             ...       ...         ...  ...    ...           ...
# 409122      8473907         1           1   12      2            73
# 409123      8473908         1           1   12      1            54
# 409124      8473908         1           2   12      1            54
# 409125      8473908         1           3   12      1            54
# 409126      8473908         1           4   12      1            54
#
#         factor_expansion  poblacion_total  sexo  edad  grupo_etnico  \
# 0                  27.75                1     1    72             6
# 1                  27.75                1     2    34             6
# 2                  59.11                1     1    45             6
# 3                  59.11                1     2    50             6
# 4                  59.11                1     1    19             6
# ...                  ...              ...   ...   ...           ...
# 409122            378.31                1     2    61             6
# 409123            534.55                1     1    58             6
# 409124            534.55                1     2    51             6
# 409125            534.55                1     2    31             6
# 409126            534.55                1     2    26             6
#
#         nivel_educativo  ocupados  categoria_ocupacional  cod_ciiu  \
# 0                   NaN      1.00                   7.00    143.00
# 1                   NaN       NaN                    NaN       NaN
# 2                   NaN      1.00                   1.00    141.00
# 3                   NaN       NaN                    NaN       NaN
# 4                   NaN      1.00                   7.00    141.00
# ...                 ...       ...                    ...       ...
# 409122              NaN      1.00                   3.00  9,700.00
# 409123             9.00      1.00                   2.00  8,530.00
# 409124             9.00      1.00                   2.00  8,412.00
# 409125             7.00       NaN                    NaN       NaN
# 409126             7.00      1.00                   4.00  4,791.00
#
#         ingreso_laboral                                          desc_ciiu  \
# 0            790,000.00                            Cría de ovejas y cabras
# 1                  0.00                                                NaN
# 2          1,100,000.00                   Cría de ganado bovino y bufalino
# 3                  0.00                                                NaN
# 4            820,000.00                   Cría de ganado bovino y bufalino
# ...                 ...                                                ...
# 409122     1,400,000.00  Actividades de los hogares individuales como e...
# 409123     3,000,000.00  Establecimientos que combinan diferentes nivel...
# 409124     7,956,000.00  Actividades ejecutivas de la administración pú...
# 409125             0.00                                                NaN
# 409126       500,000.00  Comercio al por menor realizado a través de in...
#
#                nombre_dpto
# 0                ATLÁNTICO
# 1                ATLÁNTICO
# 2                ATLÁNTICO
# 3                ATLÁNTICO
# 4                ATLÁNTICO
# ...                    ...
# 409122              TOLIMA
# 409123  NORTE DE SANTANDER
# 409124  NORTE DE SANTANDER
# 409125  NORTE DE SANTANDER
# 409126  NORTE DE SANTANDER
#
# [409127 rows x 18 columns]

# %% [markdown]
# # Ejercicio 5: Decodificar variables

# %% [markdown]
# Las variables categóricas a menudo necesitan ser "traducidas" para hacerlas más entendibles para el análisis.

# %% [markdown]
# 1. Usa los siguientes diccionarios para reemplazar los códigos numéricos por etiquetas de texto en las siguientes columnas: 'clase', 'sexo', 'grupo_etnico', 'nivel_educativo' y 'categoria_ocupacional'. Muestra los conteos de las nuevas categorías usando `.value_counts()` para verificar el cambio en cada una de las columnas.

# %%
dic_clase = {1: 'Cabeceras', 2: 'Centros poblados y rural disperso'}
dic_sexo = {1: 'Hombre', 2: 'Mujer'}
dic_etnico = {1: 'Indígena', 2: 'Gitano (Rom)', 3: 'Raizal del archipiélago', 4: 'Palenquero',
              5: 'Negro, mulato (afrodescendiente)', 6: 'Ninguno de los anteriores'}
dic_nivel_educativo = {1: 'Ninguno', 2: 'Educación media', 3: 'Educación media',
                       4: 'Educación media', 5: 'Técnica profesional', 6: 'Tecnológica',
                       7: 'Universitaria', 8: 'Especialización', 9: 'Maestría',
                       10: 'Doctorado', 99: 'No sabe, no informa'}
dic_cat_ocu = {1: 'Asalariado', 2: 'Asalariado', 3: 'Asalariado',
               8: 'Asalariado', 4: 'Independiente', 5: 'Independiente',
               9: 'Independiente', 6: 'Trabajador sin remuneración',
               7: 'Trabajador sin remuneración'}

# %%
### TU CÓDIGO AQUÍ ###
df_empleo['clase'] = df_empleo['clase'].map(dic_clase)
df_empleo['clase'].value_counts()
# Out:
# clase
# Cabeceras                            356377
# Centros poblados y rural disperso     52750
# Name: count, dtype: int64

# %%
### TU CÓDIGO AQUÍ ###
df_empleo['sexo'] = df_empleo['sexo'].map(dic_sexo)
df_empleo['sexo'].value_counts()
# Out:
# sexo
# Mujer     218597
# Hombre    190530
# Name: count, dtype: int64

# %%
### TU CÓDIGO AQUÍ ###
df_empleo['grupo_etnico'] = df_empleo['grupo_etnico'].map(dic_etnico)
df_empleo['grupo_etnico'].value_counts()
# Out:
# grupo_etnico
# Ninguno de los anteriores           350562
# Negro, mulato (afrodescendiente)     39032
# Indígena                             18420
# Raizal del archipiélago                925
# Palenquero                             120
# Gitano (Rom)                            68
# Name: count, dtype: int64

# %%
### TU CÓDIGO AQUÍ ###
df_empleo['nivel_educativo'] = df_empleo['nivel_educativo'].map(dic_nivel_educativo)
df_empleo['nivel_educativo'].value_counts()
# Out:
# nivel_educativo
# Educación media        116635
# Universitaria           32517
# Técnica profesional     24503
# Ninguno                 12963
# Tecnológica             10640
# Especialización          7927
# Maestría                 3154
# Doctorado                 339
# No sabe, no informa         1
# Name: count, dtype: int64

# %%
### TU CÓDIGO AQUÍ ###
df_empleo['categoria_ocupacional'] = df_empleo['categoria_ocupacional'].map(dic_cat_ocu)
df_empleo['categoria_ocupacional'].value_counts()
# Out:
# categoria_ocupacional
# Asalariado                     92016
# Independiente                  82498
# Trabajador sin remuneración     7339
# Name: count, dtype: int64

# %% [markdown]
# # Ejercicio 6: Reorganizar columnas

# %% [markdown]
# 1. Reorganiza las columnas con el siguiente orden: 'id_vivienda', 'id_hogar', 'id_persona', 'mes', 'clase', 'departamento', 'nombre_dpto',     'factor_expansion', 'poblacion_total', 'sexo', 'edad', 'grupo_etnico', 'nivel_educativo', 'ocupados', 'categoria_ocupacional', 'cod_ciiu', 'desc_ciiu', 'ingreso_laboral'

# %%
### TU CÓDIGO AQUÍ ###
orden_columnas = ['id_vivienda', 'id_hogar', 'id_persona', 'mes', 'clase', 'departamento', 'nombre_dpto',
                  'factor_expansion', 'poblacion_total', 'sexo', 'edad', 'grupo_etnico', 'nivel_educativo',
                  'ocupados', 'categoria_ocupacional', 'cod_ciiu', 'desc_ciiu', 'ingreso_laboral']
df_empleo = df_empleo[orden_columnas]
df_empleo.head()
# Out:
#    id_vivienda  id_hogar  id_persona  mes                              clase  \
# 0      8283143         1           1    7  Centros poblados y rural disperso
# 1      8283143         1           2    7  Centros poblados y rural disperso
# 2      8283145         1           1    7  Centros poblados y rural disperso
# 3      8283145         1           2    7  Centros poblados y rural disperso
# 4      8283145         1           3    7  Centros poblados y rural disperso
#
#    departamento nombre_dpto  factor_expansion  poblacion_total    sexo  edad  \
# 0             8   ATLÁNTICO             27.75                1  Hombre    72
# 1             8   ATLÁNTICO             27.75                1   Mujer    34
# 2             8   ATLÁNTICO             59.11                1  Hombre    45
# 3             8   ATLÁNTICO             59.11                1   Mujer    50
# 4             8   ATLÁNTICO             59.11                1  Hombre    19
#
#                 grupo_etnico nivel_educativo  ocupados  \
# 0  Ninguno de los anteriores             NaN      1.00
# 1  Ninguno de los anteriores             NaN       NaN
# 2  Ninguno de los anteriores             NaN      1.00
# 3  Ninguno de los anteriores             NaN       NaN
# 4  Ninguno de los anteriores             NaN      1.00
#
#          categoria_ocupacional  cod_ciiu                         desc_ciiu  \
# 0  Trabajador sin remuneración    143.00           Cría de ovejas y cabras
# 1                          NaN       NaN                               NaN
# 2                   Asalariado    141.00  Cría de ganado bovino y bufalino
# 3                          NaN       NaN                               NaN
# 4  Trabajador sin remuneración    141.00  Cría de ganado bovino y bufalino
#
#    ingreso_laboral
# 0       790,000.00
# 1             0.00
# 2     1,100,000.00
# 3             0.00
# 4       820,000.00

# %% [markdown]
# # Ejercicio 7: Cambiar tipo de dato

# %% [markdown]
# Para realizar cálculos y análisis correctamente, las columnas deben tener el tipo de dato adecuado (numérico, categórico, etc.).

# %% [markdown]
# 1.  Muestra en pantalla los tipos de datos actuales de `df_empleo`.

# %%
### TU CÓDIGO AQUÍ ###
df_empleo.dtypes
# Out:
# id_vivienda                int64
# id_hogar                   int64
# id_persona                 int64
# mes                        int64
# clase                     object
# departamento               int64
# nombre_dpto               object
# factor_expansion         float64
# poblacion_total            int64
# sexo                      object
# edad                       int64
# grupo_etnico              object
# nivel_educativo           object
# ocupados                 float64
# categoria_ocupacional     object
# cod_ciiu                 float64
# desc_ciiu                 object
# ingreso_laboral          float64
# dtype: object

# %% [markdown]
# 2.  Las siguientes columnas representan categorías: 'clase', 'departamento', 'nombre_dpto', 'sexo', 'grupo_etnico', 'nivel_educativo', 'categoria_ocupacional', 'cod_ciiu', 'desc_ciiu'. Conviértelas al tipo `category` para optimizar el uso de memoria y facilitar análisis futuros.

# %%
### TU CÓDIGO AQUÍ ###
columnas_categorias = ['clase', 'departamento', 'nombre_dpto', 'sexo', 'grupo_etnico', 'nivel_educativo','categoria_ocupacional', 'cod_ciiu', 'desc_ciiu']
for columna in columnas_categorias:
    df_empleo[columna] = df_empleo[columna].astype('category')

# %%
df_empleo.dtypes
# Out:
# id_vivienda                 int64
# id_hogar                    int64
# id_persona                  int64
# mes                         int64
# clase                    category
# departamento             category
# nombre_dpto              category
# factor_expansion          float64
# poblacion_total             int64
# sexo                     category
# edad                        int64
# grupo_etnico             category
# nivel_educativo          category
# ocupados                  float64
# categoria_ocupacional    category
# cod_ciiu                 category
# desc_ciiu                category
# ingreso_laboral           float64
# dtype: object

# %% [markdown]
# # Ejercicio 8: Ordenar el dataframe (5%)

# %% [markdown]
# 1. Ordena el dataframe por la columna "edad" de mayor a menor. Observa la columna 'edad' y escribe en una celda de markdown cuál fue la edad mínima y la edad máxima de las personas que respondieron la encuesta de la GEIH.

# %%
### TU CÓDIGO AQUÍ ###
df_empleo = df_empleo.sort_values(by='edad', ascending=False)
df_empleo.head()
# Out:
#         id_vivienda  id_hogar  id_persona  mes  \
# 256896      8395695         1           1   10
# 5135        8286476         1           5    7
# 32904       8299104         1           3    7
# 256662      8395585         1           3   10
# 396633      8468208         1           4   12
#
#                                     clase departamento   nombre_dpto  \
# 256896                          Cabeceras           18       CAQUETÁ
# 5135                            Cabeceras           27         CHOCÓ
# 32904   Centros poblados y rural disperso           13       BOLÍVAR
# 256662                          Cabeceras           17        CALDAS
# 396633  Centros poblados y rural disperso           25  CUNDINAMARCA
#
#         factor_expansion  poblacion_total   sexo  edad  \
# 256896             40.61                1  Mujer   108
# 5135               31.65                1  Mujer   108
# 32904             128.58                1  Mujer   106
# 256662             66.42                1  Mujer   106
# 396633          1,231.96                1  Mujer   106
#
#                             grupo_etnico nivel_educativo  ocupados  \
# 256896         Ninguno de los anteriores             NaN       NaN
# 5135    Negro, mulato (afrodescendiente)             NaN       NaN
# 32904   Negro, mulato (afrodescendiente)             NaN       NaN
# 256662         Ninguno de los anteriores             NaN       NaN
# 396633         Ninguno de los anteriores             NaN       NaN
#
#        categoria_ocupacional cod_ciiu desc_ciiu  ingreso_laboral
# 256896                   NaN      NaN       NaN             0.00
# 5135                     NaN      NaN       NaN             0.00
# 32904                    NaN      NaN       NaN             0.00
# 256662                   NaN      NaN       NaN             0.00
# 396633                   NaN      NaN       NaN             0.00

# %%
edad_minima = df_empleo['edad'].min()
edad_maxima = df_empleo['edad'].max()
print(f"La edad mínima es: {edad_minima}")
print(f"La edad máxima es: {edad_maxima}")
# Out:
# La edad mínima es: 0
# La edad máxima es: 108

# %% [markdown]
# Escribe tu análisis aquí: la edad minima encontrada es de 0 mientras que la edad maxima fue de 108

# %% [markdown]
# # Ejercicio 9: Groupby

# %% [markdown]
# Agrupar los datos por categorías, nos permite realizar análisis más profundos y obtener insights valiosos, que a simple vista no vemos en la base de datos.

# %% [markdown]
# 1. Crea un nuevo dataframe llamado "df_sexo" donde se agrupe por 'sexo' y se calcule la suma de las columnas 'poblacion_total' y 'ocupados'. Crea una nueva columna que se llame 'porcentaje_ocupados' donde dividas las columna 'ocupados' sobre 'poblacion_total'. Al final usa reset_index() para convertir las categorías de sexo en una columna.

# %%
### TU CÓDIGO AQUÍ ###
df_sexo = df_empleo.groupby('sexo')[['poblacion_total', 'ocupados']].sum()
df_sexo['porcentaje_ocupados'] = df_sexo['ocupados'] / df_sexo['poblacion_total']
df_sexo = df_sexo.reset_index()
df_sexo
# Out:
# /tmp/ipykernel_231/1757091942.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_sexo = df_empleo.groupby('sexo')[['poblacion_total', 'ocupados']].sum()
#      sexo  poblacion_total   ocupados  porcentaje_ocupados
# 0  Hombre           190530 100,790.00                 0.53
# 1   Mujer           218597  81,063.00                 0.37

# %% [markdown]
# 2. Crea un nuevo dataframe llamado "df_educacion" donde se agrupe por 'nivel_educativo' y se calcule la suma de las columnas 'poblacion_total' y 'ocupados'. Crea una nueva columna que se llame 'porcentaje_ocupados' donde dividas las columna 'ocupados' sobre 'poblacion_total'. Al final usa reset_index() para convertir las categorías de nivel educativo en una columna.

# %%
### TU CÓDIGO AQUÍ ###
df_educacion = df_empleo.groupby('nivel_educativo')[['poblacion_total', 'ocupados']].sum()
df_educacion['porcentaje_ocupados'] = df_educacion['ocupados'] / df_educacion['poblacion_total']
df_educacion = df_educacion.reset_index()
df_educacion
# Out:
# /tmp/ipykernel_231/3731727855.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_educacion = df_empleo.groupby('nivel_educativo')[['poblacion_total', 'ocupados']].sum()
#        nivel_educativo  poblacion_total  ocupados  porcentaje_ocupados
# 0            Doctorado              339    294.00                 0.87
# 1      Educación media           116635 66,945.00                 0.57
# 2      Especialización             7927  6,269.00                 0.79
# 3             Maestría             3154  2,701.00                 0.86
# 4              Ninguno            12963  2,539.00                 0.20
# 5  No sabe, no informa                1      1.00                 1.00
# 6          Tecnológica            10640  7,928.00                 0.75
# 7  Técnica profesional            24503 16,989.00                 0.69
# 8        Universitaria            32517 23,461.00                 0.72

# %% [markdown]
# 3. En una celda de Markdown escribe qué conclusiones puedes sacar de la información obtenida en df_sexo y df_educacion.

# %% [markdown]
# Escribe tu análisis aquí:
# 1. Al analizar el df_sexo podemos ver que hay una difetencia en el porcentaje de ocupads lo que puede llegar a reflejar una brecha de desigualdad de gerenero en el acceso al trabajo
# 2. Por otra parte al analizar el df_educacion podemos ver que el nivel de educación influye en el acceso al trabajo,entre mayor es el nivel de educacion mayor es el porcentaje de ocupación

# %% [markdown]
# # Ejercicio 10: Filtrar datos

# %% [markdown]
# 1. A partir de df_empleo, crea el DataFrame `df_ing` con observaciones donde `ingreso_laboral` no sea nulo y además sea mayor estrictamente al salario mínimo para 2026 (con subsidio de transporte).

# %%
### TU CÓDIGO AQUÍ ###
df_ing = df_empleo[df_empleo['ingreso_laboral']>2000000]

# %% [markdown]
# 2. ¿Cuántas personas tienen un salario estrictamente mayor al salario mínimo?

# %%
### TU CÓDIGO AQUÍ ###
df_ing.shape[0]
# Out:
# 38093

# %% [markdown]
# 3. Crea el dataframe df_mujeres donde se encuentren solamente mujeres que están ubicadas en el departamento del Tolima, que son asalariadas y cuyo nivel educativo es educación media o superior.

# %%
### TU CÓDIGO AQUÍ ###
df_mujeres = df_empleo[(df_empleo['sexo'] == 'Mujer') & (df_empleo['nombre_dpto'] == 'TOLIMA') &
                       (df_empleo['categoria_ocupacional'] == 'Asalariado') &
                        (df_empleo['nivel_educativo']).isin(['Educación media', 'Técnica profesional',
                                                             'Tecnológica', 'Universitaria', 'Especialización',
                                                             'Maestría', 'Doctorado'])]
df_mujeres.head()
# Out:
#         id_vivienda  id_hogar  id_persona  mes      clase departamento  \
# 204009      8373281         1           1    9  Cabeceras           73
# 341096      8435212         1           1   11  Cabeceras           73
# 83927       8323356         1           1    8  Cabeceras           73
# 391232      8465937         1           2   12  Cabeceras           73
# 226543      8383161         1           1   10  Cabeceras           73
#
#        nombre_dpto  factor_expansion  poblacion_total   sexo  edad  \
# 204009      TOLIMA            309.84                1  Mujer    76
# 341096      TOLIMA            379.47                1  Mujer    68
# 83927       TOLIMA            407.65                1  Mujer    67
# 391232      TOLIMA            310.36                1  Mujer    67
# 226543      TOLIMA            285.20                1  Mujer    67
#
#                      grupo_etnico      nivel_educativo  ocupados  \
# 204009  Ninguno de los anteriores      Educación media      1.00
# 341096  Ninguno de los anteriores  Técnica profesional      1.00
# 83927   Ninguno de los anteriores      Especialización      1.00
# 391232  Ninguno de los anteriores      Especialización      1.00
# 226543  Ninguno de los anteriores        Universitaria      1.00
#
#        categoria_ocupacional cod_ciiu  \
# 204009            Asalariado 8,530.00
# 341096            Asalariado 6,820.00
# 83927             Asalariado 8,530.00
# 391232            Asalariado 8,530.00
# 226543            Asalariado 8,530.00
#
#                                                 desc_ciiu  ingreso_laboral
# 204009  Establecimientos que combinan diferentes nivel...     1,423,500.00
# 341096  Actividades inmobiliarias realizadas a cambio ...       950,000.00
# 83927   Establecimientos que combinan diferentes nivel...     5,700,000.00
# 391232  Establecimientos que combinan diferentes nivel...     4,700,000.00
# 226543  Establecimientos que combinan diferentes nivel...     3,500,000.00

# %% [markdown]
# 4. ¿Cuáles son las dimensiones de df_mujeres?

# %%
### TU CÓDIGO AQUÍ ###
df_mujeres.shape
# Out:
# (1137, 18)
